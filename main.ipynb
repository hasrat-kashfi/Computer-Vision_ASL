# %% [markdown]
# <a href="https://colab.research.google.com/github/hasrat-kashfi/Computer-Vision_ASL/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

from google.colab import drive
drive.mount('/content/drive')
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/data.zip
# Out:
# Archive:  /content/drive/MyDrive/data.zip
#    creating: data/train/
#    creating: data/train/A/
#   inflating: data/train/A/A-49.jpg
#   inflating: data/train/A/A-50.jpg
#   inflating: data/train/A/A-51.jpg
#   inflating: data/train/A/A-52.jpg
#   inflating: data/train/A/A-53.jpg
#   inflating: data/train/A/A-54.jpg
#   inflating: data/train/A/A-55.jpg
#   inflating: data/train/A/A-56.jpg
#   inflating: data/train/A/A-57.jpg
#   inflating: data/train/A/A-58.jpg
#   inflating: data/train/A/A-59.jpg
#   inflating: data/train/A/A-60.jpg
#    creating: data/train/B/
#   inflating: data/train/B/B-49.jpg
#   inflating: data/train/B/B-50.jpg
#   inflating: data/train/B/B-51.jpg
#    creating: data/train/C/
#   inflating: data/train/C/C-49.jpg
#   inflating: data/train/C/C-50.jpg
#   inflating: data/train/C/C-51.jpg
#   inflating: data/train/C/C-52.jpg
#   inflating: data/train/C/C-53.jpg
#   inflating: data/train/C/C-54.jpg
#   inflating: data/train/C/C-55.jpg
# ...

# %%
from ultralytics import YOLO

model = YOLO('/content/drive/MyDrive/yolo11x-cls.pt')

model.train(data='data', epochs=10)
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !zip -r data.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/classify/ (stored 0%)
#   adding: content/runs/classify/train2/ (stored 0%)
#   adding: content/runs/classify/train2/weights/ (stored 0%)
#   adding: content/runs/classify/train2/args.yaml (deflated 52%)
#   adding: content/runs/classify/train4/ (stored 0%)
#   adding: content/runs/classify/train4/results.png (deflated 7%)
#   adding: content/runs/classify/train4/val_batch2_pred.jpg (deflated 3%)
#   adding: content/runs/classify/train4/events.out.tfevents.1730872621.b8f5b02e4933.791.0 (deflated 95%)
#   adding: content/runs/classify/train4/weights/ (stored 0%)
#   adding: content/runs/classify/train4/weights/last.pt (deflated 8%)
#   adding: content/runs/classify/train4/weights/best.pt (deflated 8%)
#   adding: content/runs/classify/train4/train_batch0.jpg (deflated 4%)
#   adding: content/runs/classify/train4/results.csv (deflated 58%)
# ...

# %%
from google.colab import files
files.download('data.zip')

# %%
from google.colab import files
files.download('/content/data/train.cache')
files.download('/content/data/val.cache')

# %%
model= YOLO('runs/classify/train4/weights/best.pt')
metrics = model.val()
print(metrics)
# Out:
# Ultralytics 8.3.27 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11x-cls summary (fused): 227 layers, 28,365,722 parameters, 0 gradients, 110.4 GFLOPs
# train: /content/data/train... found 287 images in 26 classes ✅
# val: /content/data/val... found 1248 images in 26 classes ✅
# test: None...
# val: Scanning /content/data/val... 1248 images, 0 corrupt: 100%|██████████| 1248/1248 [00:00<?, ?it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 78/78 [00:06<00:00, 12.02it/s]
#                    all      0.642      0.909
# Speed: 0.1ms preprocess, 4.6ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to runs/classify/val
# ultralytics.utils.metrics.ClassifyMetrics object with attributes:
#
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7eb3581219f0>
# curves: []
# curves_results: []
# fitness: 0.7756410241127014
# keys: ['metrics/accuracy_top1', 'metrics/accuracy_top5']
# ...

# %%
results=model('/content/C93.jpg', save=True)
#results
for r in results:
    print(r.probs)
# Out:
# image 1/1 /content/C93.jpg: 224x224 C 0.67, O 0.06, P 0.04, X 0.04, Y 0.03, 14.1ms
# Speed: 7.3ms preprocess, 14.1ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/classify/predict
# ultralytics.engine.results.Probs object with attributes:
#
# data: tensor([0.0105, 0.0016, 0.6738, 0.0024, 0.0039, 0.0093, 0.0106, 0.0027, 0.0017, 0.0074, 0.0061, 0.0178, 0.0015, 0.0025, 0.0570, 0.0390, 0.0052, 0.0302, 0.0016, 0.0018, 0.0047, 0.0225, 0.0014, 0.0376, 0.0333, 0.0139], device='cuda:0')
# orig_shape: None
# shape: torch.Size([26])
# top1: 2
# top1conf: tensor(0.6738, device='cuda:0')
# top5: [2, 14, 15, 23, 24]
# top5conf: tensor([0.6738, 0.0570, 0.0390, 0.0376, 0.0333], device='cuda:0')
